# %% [markdown]
# # Sample Student Marksheet Database Tutorial (SQLite)
#
# This tutorial demonstrates how to create a sample students marksheet database in SQLite and use common SQL commands such as `SELECT`, `LIMIT`, `RANK`, and Common Table Expressions (CTEs).
#
# ---
#
# ## 1. Create the Database and Table
#
# ```sql
# -- Create a table for students' marks
# CREATE TABLE students (
#     id INTEGER PRIMARY KEY,
#     name TEXT NOT NULL,
#     subject TEXT NOT NULL,
#     marks INTEGER NOT NULL
# );
#
# -- Insert sample data
# INSERT INTO students (name, subject, marks) VALUES
# ('Alice', 'Math', 85),
# ('Bob', 'Math', 92),
# ('Charlie', 'Math', 78),
# ('David', 'Math', 88),
# ('Eve', 'Math', 95),
# ('Alice', 'Science', 90),
# ('Bob', 'Science', 85),
# ('Charlie', 'Science', 80),
# ('David', 'Science', 89),
# ('Eve', 'Science', 93);
# ```
#
# ---
#
# ## 2. Basic SELECT Statement
#
# ```sql
# -- Select all records from the students table
# SELECT * FROM students;
# ```
#
# ---
#
# ## 3. Using LIMIT to Get Top N Rows
#
# ```sql
# -- Get the top 3 students (by marks) in Math
# SELECT name, marks
# FROM students
# WHERE subject = 'Math'
# ORDER BY marks DESC
# LIMIT 3;
# ```
#
# ---
#
# ## 4. Ranking Students Using RANK()
#
# SQLite supports window functions (version 3.25+):
#
# ```sql
# -- Rank students in Science by their marks
# SELECT
#     name,
#     marks,
#     RANK() OVER (ORDER BY marks DESC) AS rank
# FROM students
# WHERE subject = 'Science';
# ```
#
# ---
#
# ## 5. Using Common Table Expressions (CTEs)
#
# ```sql
# -- Use a CTE to find average marks per subject, then select students above average
# WITH avg_marks AS (
#     SELECT subject, AVG(marks) AS avg_mark
#     FROM students
#     GROUP BY subject
# )
# SELECT s.name, s.subject, s.marks
# FROM students s
# JOIN avg_marks a ON s.subject = a.subject
# WHERE s.marks > a.avg_mark;
# ```
#
# ---
#
# ## Summary
#
# - **SELECT**: Retrieve data from tables.
# - **LIMIT**: Restrict the number of rows returned.
# - **RANK()**: Assign ranks to rows within a partition.
# - **CTE (WITH)**: Create temporary result sets for complex queries.
#
# You can run these SQL commands in any SQLite environment to practice and explore further!

# %%
# Check if a string s1 is a part of another string s2

s1 = "hello"
s2 = "helloworld"

# Check if s1 is in s2
if s1 in s2:
    print(f"'{s1}' is a part of '{s2}'")
# Out:
# 'hello' is a part of 'helloworld'

# %%
## Sort a string
s = "helloworldhello"
# Sort the string
s_sorted = ''.join(sorted(s))
print(f"Sorted string: {s_sorted}")
# Out:
# Sorted string: deehhlllllooorw

# %%
def min_operations_to_palindrome(sub):
    # Count the number of positions where characters differ from their mirror
    count = 0
    n = len(sub)
    for i in range(n // 2):
        if sub[i] != sub[-(i + 1)]:
            count += 1
    return count

k = 5  # You can set k to any value you want

for i in range(len(s)):
    for j in range(i + 1, len(s) + 1):
        substring = s[i:j]
        ops = min_operations_to_palindrome(substring)
        if ops <= k:
            print(f"'{substring}' can be made palindrome with at most {k} operations (needs {ops})")


# Check if a string is a palindrome
s = "madamad"
k = 4
# Out:
# 'h' can be made palindrome with at most 5 operations (needs 0)
# 'he' can be made palindrome with at most 5 operations (needs 1)
# 'hel' can be made palindrome with at most 5 operations (needs 1)
# 'hell' can be made palindrome with at most 5 operations (needs 2)
# 'hello' can be made palindrome with at most 5 operations (needs 2)
# 'e' can be made palindrome with at most 5 operations (needs 0)
# 'el' can be made palindrome with at most 5 operations (needs 1)
# 'ell' can be made palindrome with at most 5 operations (needs 1)
# 'ello' can be made palindrome with at most 5 operations (needs 1)
# 'l' can be made palindrome with at most 5 operations (needs 0)
# 'll' can be made palindrome with at most 5 operations (needs 0)
# 'llo' can be made palindrome with at most 5 operations (needs 1)
# 'l' can be made palindrome with at most 5 operations (needs 0)
# 'lo' can be made palindrome with at most 5 operations (needs 1)
# 'o' can be made palindrome with at most 5 operations (needs 0)
